# %%
import geopandas as gpd

# %%
# %matplotlib inline

# %%
shpfile = '/Users/yy/Downloads/tl_2017_us_zcta510/tl_2017_us_zcta510.shp'
us = gpd.read_file(shpfile)

# %%
us.head()
# Out:
#   ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0     43451   43451        B5   G6350          S   63411475    157689
# 1     43452   43452        B5   G6350          S  121783674  13437380
# 2     43456   43456        B5   G6350          S    9389362    999166
# 3     43457   43457        B5   G6350          S   48035540         0
# 4     43458   43458        B5   G6350          S    2573816     39915
#
#     INTPTLAT10    INTPTLON10  \
# 0  +41.3183010  -083.6174935
# 1  +41.5157923  -082.9809454
# 2  +41.6468445  -082.8226641
# 3  +41.2673266  -083.4274645
# 4  +41.5304461  -083.2133648
#
#                                             geometry
# 0  POLYGON ((-83.708733 41.327326, -83.708147 41....
# 1  POLYGON ((-83.086978 41.537796, -83.0825629999...
# 2  (POLYGON ((-82.835577 41.710823, -82.83515 41....
# 3  POLYGON ((-83.49650299999999 41.253708, -83.48...
# 4  POLYGON ((-83.222292 41.531025, -83.2222819999...

# %%
usa = us.rename(columns={'geometry': 'boundary'}).set_geometry('boundary')
usa.head()
# Out:
#   ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0     43451   43451        B5   G6350          S   63411475    157689
# 1     43452   43452        B5   G6350          S  121783674  13437380
# 2     43456   43456        B5   G6350          S    9389362    999166
# 3     43457   43457        B5   G6350          S   48035540         0
# 4     43458   43458        B5   G6350          S    2573816     39915
#
#     INTPTLAT10    INTPTLON10  \
# 0  +41.3183010  -083.6174935
# 1  +41.5157923  -082.9809454
# 2  +41.6468445  -082.8226641
# 3  +41.2673266  -083.4274645
# 4  +41.5304461  -083.2133648
#
#                                             boundary
# 0  POLYGON ((-83.708733 41.327326, -83.708147 41....
# 1  POLYGON ((-83.086978 41.537796, -83.0825629999...
# 2  (POLYGON ((-82.835577 41.710823, -82.83515 41....
# 3  POLYGON ((-83.49650299999999 41.253708, -83.48...
# 4  POLYGON ((-83.222292 41.531025, -83.2222819999...

# %%
usa.crs
# Out:
# {'init': 'epsg:4269'}

# %%
usa = usa.to_crs({'init': 'epsg:3395'})
usa.plot()

# %%
us48 = us.cx[-125.0:0, 22:].to_crs({'init': 'epsg:3395'})
us48.plot()

# %%
wa981 = usa[(usa.GEOID10 >= '98100') & (usa.GEOID10 < '98200')]
wa981.plot(figsize=(100, 50), cmap='tab20')

# %%
us[us['GEOID10'] == "98109"]
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10  ALAND10  AWATER10  \
# 18393     98109   98109        B5   G6350          S  5180653   1088479
#
#         INTPTLAT10    INTPTLON10  \
# 18393  +47.6318633  -122.3442667
#
#                                                 geometry
# 18393  POLYGON ((-122.360874 47.651931, -122.360539 4...

# %%
wa981 = usa[(usa.GEOID10 >= '98000') & (usa.GEOID10 < '98200')]
wa981.plot(figsize=(100, 50), cmap='tab20')
